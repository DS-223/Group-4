# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df = pd.read_csv('property_ml_ready.csv')
df.head(20)
# Out:
#     property_id deal_type user_type          district type_name  size_sqm  \
# 0             1      Rent     Owner  Malatia-Sebastia     House      96.1
# 1             2      Sale     Agent        Nubarashen     House      89.0
# 2             5      Rent     Buyer          Nor Nork     House     124.9
# 3             7      Rent     Agent  Malatia-Sebastia     House     181.6
# 4             9      Rent     Agent    Kanaker-Zeytun     House      63.0
# 5            12      Sale     Owner         Davtashen     House     162.6
# 6            15      Sale     Owner         Davtashen     House     128.5
# 7            16      Sale     Owner           Arabkir     House     182.9
# 8            17      Sale     Owner         Shengavit     House     197.7
# 9            24      Rent     Buyer           Erebuni     House      37.2
# 10           28      Rent     Agent        Nubarashen     House      80.1
# 11           29      Sale     Agent         Davtashen     House      46.0
# 12           32      Sale     Buyer           Erebuni     House      95.3
# 13           33      Rent     Agent           Erebuni     House      57.4
# 14           34      Rent     Agent         Davtashen     House     198.6
# 15           38      Rent     Agent              Avan     House      43.6
# 16           39      Rent     Agent    Kanaker-Zeytun     House     185.1
# 17           40      Rent     Owner         Davtashen     House     136.9
# 18           42      Sale     Owner        Nubarashen     House     108.4
# 19           45      Sale     Agent           Arabkir     House     153.6
#
#        status  rooms  floor  year_built    renovation_status  \
# 0   Available      1      9        1996      Newly Renovated
# 1   Available      6      5        1967      Newly Renovated
# 2   Available      6      8        2009        Not Renovated
# 3   Available      2      4        1989  Partially Renovated
# 4   Available      6     10        1977      Newly Renovated
# 5   Available      5      5        2006  Partially Renovated
# 6   Available      2      8        1975      Newly Renovated
# 7   Available      3      4        2008      Newly Renovated
# 8   Available      4      3        1983      Newly Renovated
# 9   Available      5      4        1994        Not Renovated
# 10  Available      6      3        1988        Not Renovated
# 11  Available      4      4        1966        Not Renovated
# 12  Available      6     11        1986      Newly Renovated
# 13  Available      2      4        2005        Not Renovated
# 14  Available      1      3        1979      Newly Renovated
# 15  Available      2      7        1970      Newly Renovated
# 16  Available      3      2        2005      Newly Renovated
# 17  Available      2     11        2011  Partially Renovated
# 18  Available      1      1        1995  Partially Renovated
# 19  Available      6      2        1989        Not Renovated
#
#     estimated_saleprice  estimated_rentprice
# 0             199007.93               796.03
# 1             211979.08               847.92
# 2             178884.09               715.54
# 3             201469.44               805.88
# 4             147790.87               591.16
# 5             306955.94              1227.82
# 6             255854.50              1023.42
# 7             504693.71              2018.77
# 8             356509.16              1426.04
# 9              44673.28               178.69
# 10            131634.49               526.54
# 11             52615.38               210.46
# 12            261148.39              1044.59
# 13             69918.33               279.67
# 14            380147.12              1520.59
# 15            124663.57               498.65
# 16            366452.77              1465.81
# 17            176296.99               705.19
# 18            202989.97               811.96
# 19            249212.51               996.85

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1423 entries, 0 to 1422
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_id          1423 non-null   int64
#  1   deal_type            1423 non-null   object
#  2   user_type            1423 non-null   object
#  3   district             1423 non-null   object
#  4   type_name            1423 non-null   object
#  5   size_sqm             1423 non-null   float64
#  6   status               1423 non-null   object
#  7   rooms                1423 non-null   int64
#  8   floor                1423 non-null   int64
#  9   year_built           1423 non-null   int64
#  10  renovation_status    1423 non-null   object
#  11  estimated_saleprice  1423 non-null   float64
#  12  estimated_rentprice  1423 non-null   float64
# dtypes: float64(3), int64(4), object(6)
# memory usage: 144.7+ KB

# %%
df.isnull().sum()
# Out:
# property_id            0
# deal_type              0
# user_type              0
# district               0
# type_name              0
# size_sqm               0
# status                 0
# rooms                  0
# floor                  0
# year_built             0
# renovation_status      0
# estimated_saleprice    0
# estimated_rentprice    0
# dtype: int64

# %%
df.duplicated().sum().any()
# Out:
# np.False_

# %%
df.dropna(inplace=True)

# %%
df.describe()
# Out:
#        property_id     size_sqm        rooms        floor   year_built  \
# count  1423.000000  1423.000000  1423.000000  1423.000000  1423.000000
# mean   1502.613493   114.713212     3.537597     6.465214  1993.248770
# std     876.017436    50.204404     1.690076     3.397280    17.006906
# min       1.000000    25.000000     1.000000     1.000000  1965.000000
# 25%     730.500000    69.850000     2.000000     4.000000  1978.000000
# 50%    1481.000000   116.800000     4.000000     6.000000  1993.000000
# 75%    2275.000000   158.500000     5.000000     9.000000  2008.000000
# max    2997.000000   200.000000     6.000000    12.000000  2023.000000
#
#        estimated_saleprice  estimated_rentprice
# count          1423.000000          1423.000000
# mean         221190.432586           884.761862
# std          116219.309695           464.877256
# min           28081.370000           112.330000
# 25%          128306.335000           513.225000
# 50%          208308.930000           833.240000
# 75%          291172.465000          1164.690000
# max          683244.030000          2732.980000

# %%
df.shape
# Out:
# (1423, 13)

# %%
# Define categorical columns
categorical_cols = ['type_name', 'district', 'status', 'renovation_status']

# One-hot encode categorical columns
df_encoded = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

# Features to exclude from modeling
exclude_columns = ['estimated_rent_price', 'estimated_sales_price', 'id', 'property_id',
 'deal_type',
 'user_type',]

# Determine which columns are features
all_columns = df_encoded.columns.tolist()
feature_columns = [col for col in all_columns if col not in exclude_columns]
feature_columns
# Out:
# ['size_sqm',
#  'rooms',
#  'floor',
#  'year_built',
#  'estimated_saleprice',
#  'estimated_rentprice',
#  'district_Arabkir',
#  'district_Avan',
#  'district_Davtashen',
#  'district_Erebuni',
#  'district_Kanaker-Zeytun',
#  'district_Kentron',
#  'district_Malatia-Sebastia',
#  'district_Nor Nork',
#  'district_Nork-Marash',
#  'district_Nubarashen',
#  'district_Shengavit',
#  'renovation_status_Not Renovated',
#  'renovation_status_Partially Renovated']

# %%
def evaluate_model(model, X_test, y_test, label=""):
    y_pred = model.predict(X_test)
    print(f"\n--- {label} Model Evaluation ---")
    print("MAE:", mean_absolute_error(y_test, y_pred))
    print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
    print("R² Score:", r2_score(y_test, y_pred))

# %%
# ----------------- Rent Price Model -----------------
X_rent = df_encoded[feature_columns]
y_rent = df_encoded['estimated_rentprice']

X_train_r, X_test_r, y_train_r, y_test_r = train_test_split(X_rent, y_rent, test_size=0.2, random_state=42)

model_rent = RandomForestRegressor(n_estimators=100, random_state=42)
model_rent.fit(X_train_r, y_train_r)

evaluate_model(model_rent, X_test_r, y_test_r, label="Rent Price")
# Out:
# --- Rent Price Model Evaluation ---
# MAE: 1.8065270175438903
# RMSE: 12.818789033484327
# R² Score: 0.9992433165259985

# %%
# ----------------- Sales Price Model -----------------
X_sales = df_encoded[feature_columns]
y_sales = df_encoded['estimated_saleprice']
X_train_s, X_test_s, y_train_s, y_test_s = train_test_split(X_sales, y_sales, test_size=0.2, random_state=42)

model_sales = RandomForestRegressor(n_estimators=100, random_state=42)
model_sales.fit(X_train_s, y_train_s)

evaluate_model(model_sales, X_test_s, y_test_s, label="Sales Price")
# Out:
# --- Sales Price Model Evaluation ---
# MAE: 452.0154473684318
# RMSE: 2903.74201899575
# R² Score: 0.9993787654497182

# %%
import joblib 

joblib.dump(model_sales, 'models/sales_price_model.pkl')
joblib.dump(model_rent, 'models/rent_price_model.pkl')
# Out:
# ['models/rent_price_model.pkl']

# %%
df_encoded["predicted_rentprice"] = model_rent.predict(X_rent)
df_encoded["predicted_saleprice"] = model_sales.predict(X_sales)

# %%
prediction_df = df[['property_id']].copy()
prediction_df["actual_rentprice"] = df['estimated_rentprice']
prediction_df["predicted_rentprice"] = df_encoded["predicted_rentprice"]
prediction_df["actual_saleprice"] = df['estimated_saleprice']
prediction_df["predicted_saleprice"] = df_encoded["predicted_saleprice"]

# %%
# Save to file
output_path = "property_predictions.csv"
prediction_df.to_csv(output_path, index=False)
print(f"\n✅ Prediction CSV saved: {output_path} | Shape: {prediction_df.shape}")
# Out:
# ✅ Prediction CSV saved: property_predictions.csv | Shape: (1423, 5)

# %%
ready_df = pd.read_csv(output_path)
ready_df.head(20)
# Out:
#     property_id  actual_rentprice  predicted_rentprice  actual_saleprice  \
# 0             1            796.03             796.1628         199007.93
# 1             2            847.92             848.1204         211979.08
# 2             5            715.54             715.3291         178884.09
# 3             7            805.88             805.7927         201469.44
# 4             9            591.16             590.8618         147790.87
# 5            12           1227.82            1227.7434         306955.94
# 6            15           1023.42            1023.5662         255854.50
# 7            16           2018.77            2021.4976         504693.71
# 8            17           1426.04            1425.2995         356509.16
# 9            24            178.69             178.8727          44673.28
# 10           28            526.54             526.4916         131634.49
# 11           29            210.46             209.9858          52615.38
# 12           32           1044.59            1045.1499         261148.39
# 13           33            279.67             279.7962          69918.33
# 14           34           1520.59            1520.7764         380147.12
# 15           38            498.65             498.5725         124663.57
# 16           39           1465.81            1465.8723         366452.77
# 17           40            705.19             704.8584         176296.99
# 18           42            811.96             812.1744         202989.97
# 19           45            996.85             996.7398         249212.51
#
#     predicted_saleprice
# 0           199000.3431
# 1           212029.3268
# 2           178831.3972
# 3           201456.1499
# 4           147722.7850
# 5           306979.2861
# 6           255889.3870
# 7           505026.9673
# 8           356291.6471
# 9            44743.7420
# 10          131611.7603
# 11           52522.1534
# 12          261244.9894
# 13           69915.4084
# 14          380176.1378
# 15          124669.2287
# 16          366580.4714
# 17          176248.7490
# 18          203021.4911
# 19          249227.7221
